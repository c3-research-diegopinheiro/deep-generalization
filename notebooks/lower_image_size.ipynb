# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras import layers
from keras.regularizers import l2
from tensorflow.keras import models
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Input, Conv2D,  MaxPooling2D, ZeroPadding2D, Flatten, Dense, Activation, Dropout
from tensorflow.keras.utils import plot_model
from keras.layers.normalization import BatchNormalization

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from utils.plot_history import plot_history
import numpy as np

# %%
def compile_model(input_shape, alpha): #CRIE SEU PRÓPRIO MODELO AQUI
  model = models.Sequential()

  model.add(Input(shape=input_shape))

  model.add(Conv2D(filters=32,kernel_size=(3,3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Conv2D(filters=64,kernel_size=(3,3), activation='relu'))

  model.add(Flatten())

  model.add(Dense(128))
  model.add(Activation('relu'))

  model.add(Dropout(0.5))

  model.add(Dense(1))
  model.add(Activation('sigmoid'))

  opt = SGD(learning_rate=alpha)
  model.summary()
  model.compile(loss='binary_crossentropy',
                optimizer=opt,
                metrics=['acc'])
      
  print("Modelo Compilado...")
  return model

def data_augment(batch_size, input_shape): #Gerando novas imagens com rotações e zooms para incrementar o treino.
  image_gen = ImageDataGenerator(rotation_range= 360, rescale = 1/255, horizontal_flip= True, vertical_flip=True)

  train_images = image_gen.flow_from_directory('DATASET_2/train', target_size=input_shape[:2], batch_size=batch_size, class_mode='binary')
  test_images = image_gen.flow_from_directory('DATASET_2/test', target_size=input_shape[:2], batch_size=batch_size, class_mode='binary')

  return train_images, test_images

def create_callbacks(alpha): #Callbacks para serem aplicados no treino
  filepath="model_one.hdf5"
  checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
  # lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, min_delta=alpha, patience=5, verbose=1)

  callbacks = [checkpoint]
  return callbacks
  
def train_Model(): #Funcão para treinar o modelo
  batch_size   = 16
  alpha        = 1e-3
  epoch        = 100
  input_shape  = (128,128, 3)

  model = compile_model(input_shape, alpha)
  print("Criando Array de callbacks")
  callbacks = create_callbacks(alpha)
  print("Criando data augmentator")
  train_images, test_images = data_augment(batch_size, input_shape)
  
  print("Iniciando treino do Modelo...")
  history = model.fit(
                              train_images,
                              validation_data=test_images,
                              callbacks=callbacks,
                              epochs=epoch)

  return history, model

# %%
history, model = train_Model()
# Out:
# ____
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 30,502,081
# Trainable params: 30,502,081
# Non-trainable params: 0
# _________________________________________________________________
# Modelo Compilado...
# Criando Array de callbacks
# Criando data augmentator
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Iniciando treino do Modelo...
# Epoch 1/100
# 125/125 [==============================] - 53s 420ms/step - loss: 0.6614 - acc: 0.6116 - val_loss: 0.5910 - val_acc: 0.7070
#
# Epoch 00001: val_acc improved from -inf to 0.70700, saving model to model_one.hdf5
# Epoch 2/100
# 125/125 [==============================] - 50s 396ms/step - loss: 0.5920 - acc: 0.7075 - val_loss: 0.5734 - val_acc: 0.7020
#
# Epoch 00002: val_acc did not improve from 0.70700
# Epoch 3/100
# 125/125 [==============================] - 52s 413ms/step - loss: 0.5748 - acc: 0.7254 - val_loss: 0.5602 - val_acc: 0.7220
#
# Epoch 00003: val_acc improved from 0.70700 to 0.72200, saving model to model_one.hdf5
# Epoch 4/100
# 125/125 [==============================] - 50s 402ms/step - loss: 0.5783 - acc: 0.7108 - val_loss: 0.5573 - val_acc: 0.7250
#
# Epoch 00004: val_acc improved from 0.72200 to 0.72500, saving model to model_one.hdf5
# Epoch 5/100
# 125/125 [==============================] - 48s 386ms/step - loss: 0.5375 - acc: 0.7479 - val_loss: 0.5499 - val_acc: 0.7230
#
# Epoch 00005: val_acc did not improve from 0.72500
# Epoch 6/100
# 125/125 [==============================] - 47s 374ms/step - loss: 0.5401 - acc: 0.7438 - val_loss: 0.5514 - val_acc: 0.7270
#
# Epoch 00006: val_acc improved from 0.72500 to 0.72700, saving model to model_one.hdf5
# Epoch 7/100
# 125/125 [==============================] - 47s 374ms/step - loss: 0.5480 - acc: 0.7200 - val_loss: 0.5351 - val_acc: 0.7380
#
# Epoch 00007: val_acc improved from 0.72700 to 0.73800, saving model to model_one.hdf5
# Epoch 8/100
# 125/125 [==============================] - 46s 368ms/step - loss: 0.5327 - acc: 0.7408 - val_loss: 0.5340 - val_acc: 0.7420
#
# Epoch 00008: val_acc improved from 0.73800 to 0.74200, saving model to model_one.hdf5
# Epoch 9/100
# 125/125 [==============================] - 47s 377ms/step - loss: 0.5197 - acc: 0.7527 - val_loss: 0.5328 - val_acc: 0.7660
#
# Epoch 00009: val_acc improved from 0.74200 to 0.76600, saving model to model_one.hdf5
# Epoch 10/100
# 125/125 [==============================] - 50s 397ms/step - loss: 0.5303 - acc: 0.7397 - val_loss: 0.5622 - val_acc: 0.7240
#
# Epoch 00010: val_acc did not improve from 0.76600
# Epoch 11/100
# 125/125 [==============================] - 52s 413ms/step - loss: 0.5385 - acc: 0.7454 - val_loss: 0.5245 - val_acc: 0.7510
#
# Epoch 00011: val_acc did not improve from 0.76600
# Epoch 12/100
# 125/125 [==============================] - 49s 394ms/step - loss: 0.5214 - acc: 0.7575 - val_loss: 0.5317 - val_acc: 0.7330
#
# Epoch 00012: val_acc did not improve from 0.76600
# Epoch 13/100
# 125/125 [==============================] - 48s 383ms/step - loss: 0.5125 - acc: 0.7551 - val_loss: 0.5197 - val_acc: 0.7530
#
# Epoch 00013: val_acc did not improve from 0.76600
# Epoch 14/100
# 125/125 [==============================] - 49s 393ms/step - loss: 0.4975 - acc: 0.7767 - val_loss: 0.5169 - val_acc: 0.7800
#
# Epoch 00014: val_acc improved from 0.76600 to 0.78000, saving model to model_one.hdf5
# Epoch 15/100
# 125/125 [==============================] - 52s 413ms/step - loss: 0.5115 - acc: 0.7662 - val_loss: 0.5093 - val_acc: 0.7790
#
# Epoch 00015: val_acc did not improve from 0.78000
# Epoch 16/100
# 125/125 [==============================] - 47s 378ms/step - loss: 0.5056 - acc: 0.7574 - val_loss: 0.5160 - val_acc: 0.7740
#
# Epoch 00016: val_acc did not improve from 0.78000
# Epoch 17/100
# 125/125 [==============================] - 47s 377ms/step - loss: 0.5131 - acc: 0.7607 - val_loss: 0.5062 - val_acc: 0.7800
#
# Epoch 00017: val_acc did not improve from 0.78000
# Epoch 18/100
# 125/125 [==============================] - 49s 393ms/step - loss: 0.5051 - acc: 0.7530 - val_loss: 0.5054 - val_acc: 0.7840
#
# Epoch 00018: val_acc improved from 0.78000 to 0.78400, saving model to model_one.hdf5
# Epoch 19/100
# 125/125 [==============================] - 48s 379ms/step - loss: 0.4920 - acc: 0.7674 - val_loss: 0.5130 - val_acc: 0.7610
#
# Epoch 00019: val_acc did not improve from 0.78400
# Epoch 20/100
# 125/125 [==============================] - 47s 378ms/step - loss: 0.4809 - acc: 0.7726 - val_loss: 0.5051 - val_acc: 0.7880
#
# Epoch 00020: val_acc improved from 0.78400 to 0.78800, saving model to model_one.hdf5
# Epoch 21/100
# 125/125 [==============================] - 46s 369ms/step - loss: 0.5001 - acc: 0.7470 - val_loss: 0.4976 - val_acc: 0.7870
#
# Epoch 00021: val_acc did not improve from 0.78800
# Epoch 22/100
# 125/125 [==============================] - 47s 375ms/step - loss: 0.5036 - acc: 0.7580 - val_loss: 0.5002 - val_acc: 0.7820
#
# Epoch 00022: val_acc did not improve from 0.78800
# Epoch 23/100
# 125/125 [==============================] - 48s 382ms/step - loss: 0.4914 - acc: 0.7690 - val_loss: 0.4995 - val_acc: 0.7730
#
# Epoch 00023: val_acc did not improve from 0.78800
# Epoch 24/100
# 125/125 [==============================] - 45s 358ms/step - loss: 0.4705 - acc: 0.7946 - val_loss: 0.5237 - val_acc: 0.7380
#
# Epoch 00024: val_acc did not improve from 0.78800
# Epoch 25/100
# 125/125 [==============================] - 46s 371ms/step - loss: 0.4988 - acc: 0.7662 - val_loss: 0.4935 - val_acc: 0.7800
#
# Epoch 00025: val_acc did not improve from 0.78800
# Epoch 26/100
# 125/125 [==============================] - 46s 364ms/step - loss: 0.4948 - acc: 0.7705 - val_loss: 0.4951 - val_acc: 0.7830
#
# Epoch 00026: val_acc did not improve from 0.78800
# Epoch 27/100
# 125/125 [==============================] - 49s 394ms/step - loss: 0.4801 - acc: 0.7683 - val_loss: 0.4946 - val_acc: 0.7900
#
# Epoch 00027: val_acc improved from 0.78800 to 0.79000, saving model to model_one.hdf5
# Epoch 28/100
# 125/125 [==============================] - 45s 362ms/step - loss: 0.4761 - acc: 0.7826 - val_loss: 0.4937 - val_acc: 0.7750
#
# Epoch 00028: val_acc did not improve from 0.79000
# Epoch 29/100
# 125/125 [==============================] - 43s 343ms/step - loss: 0.4741 - acc: 0.7708 - val_loss: 0.4914 - val_acc: 0.7850
#
# Epoch 00029: val_acc did not improve from 0.79000
# Epoch 30/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.4878 - acc: 0.7685 - val_loss: 0.4943 - val_acc: 0.7670
#
# Epoch 00030: val_acc did not improve from 0.79000
# Epoch 31/100
# 125/125 [==============================] - 50s 402ms/step - loss: 0.4856 - acc: 0.7749 - val_loss: 0.4870 - val_acc: 0.7780
#
# Epoch 00031: val_acc did not improve from 0.79000
# Epoch 32/100
# 125/125 [==============================] - 50s 399ms/step - loss: 0.4872 - acc: 0.7622 - val_loss: 0.4836 - val_acc: 0.7820
#
# Epoch 00032: val_acc did not improve from 0.79000
# Epoch 33/100
# 125/125 [==============================] - 46s 366ms/step - loss: 0.4846 - acc: 0.7658 - val_loss: 0.4828 - val_acc: 0.7810
#
# Epoch 00033: val_acc did not improve from 0.79000
# Epoch 34/100
# 125/125 [==============================] - 50s 400ms/step - loss: 0.4667 - acc: 0.7750 - val_loss: 0.4802 - val_acc: 0.7680
#
# Epoch 00034: val_acc did not improve from 0.79000
# Epoch 35/100
# 125/125 [==============================] - 45s 361ms/step - loss: 0.4624 - acc: 0.7901 - val_loss: 0.4782 - val_acc: 0.7840
#
# Epoch 00035: val_acc did not improve from 0.79000
# Epoch 36/100
# 125/125 [==============================] - 44s 352ms/step - loss: 0.4927 - acc: 0.7696 - val_loss: 0.4862 - val_acc: 0.7610
#
# Epoch 00036: val_acc did not improve from 0.79000
# Epoch 37/100
# 125/125 [==============================] - 46s 370ms/step - loss: 0.4599 - acc: 0.7765 - val_loss: 0.4736 - val_acc: 0.7870
#
# Epoch 00037: val_acc did not improve from 0.79000
# Epoch 38/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.4690 - acc: 0.7740 - val_loss: 0.4781 - val_acc: 0.7800
#
# Epoch 00038: val_acc did not improve from 0.79000
# Epoch 39/100
# 125/125 [==============================] - 45s 360ms/step - loss: 0.4743 - acc: 0.7743 - val_loss: 0.4709 - val_acc: 0.7920
#
# Epoch 00039: val_acc improved from 0.79000 to 0.79200, saving model to model_one.hdf5
# Epoch 40/100
# 125/125 [==============================] - 46s 370ms/step - loss: 0.4632 - acc: 0.7823 - val_loss: 0.4747 - val_acc: 0.7720
#
# Epoch 00040: val_acc did not improve from 0.79200
# Epoch 41/100
# 125/125 [==============================] - 47s 375ms/step - loss: 0.4731 - acc: 0.7712 - val_loss: 0.4727 - val_acc: 0.7910
#
# Epoch 00041: val_acc did not improve from 0.79200
# Epoch 42/100
# 125/125 [==============================] - 46s 368ms/step - loss: 0.4686 - acc: 0.7730 - val_loss: 0.4840 - val_acc: 0.7870
#
# Epoch 00042: val_acc did not improve from 0.79200
# Epoch 43/100
# 125/125 [==============================] - 49s 390ms/step - loss: 0.4601 - acc: 0.7881 - val_loss: 0.4672 - val_acc: 0.7840
#
# Epoch 00043: val_acc did not improve from 0.79200
# Epoch 44/100
# 125/125 [==============================] - 47s 378ms/step - loss: 0.4615 - acc: 0.7913 - val_loss: 0.4748 - val_acc: 0.7680
#
# Epoch 00044: val_acc did not improve from 0.79200
# Epoch 45/100
# 125/125 [==============================] - 49s 392ms/step - loss: 0.4599 - acc: 0.7741 - val_loss: 0.4751 - val_acc: 0.7840
#
# Epoch 00045: val_acc did not improve from 0.79200
# Epoch 46/100
# 125/125 [==============================] - 48s 382ms/step - loss: 0.4588 - acc: 0.7871 - val_loss: 0.4601 - val_acc: 0.7790
#
# Epoch 00046: val_acc did not improve from 0.79200
# Epoch 47/100
# 125/125 [==============================] - 49s 390ms/step - loss: 0.4323 - acc: 0.7953 - val_loss: 0.4618 - val_acc: 0.7860
#
# Epoch 00047: val_acc did not improve from 0.79200
# Epoch 48/100
# 125/125 [==============================] - 49s 388ms/step - loss: 0.4701 - acc: 0.7669 - val_loss: 0.4626 - val_acc: 0.7740
#
# Epoch 00048: val_acc did not improve from 0.79200
# Epoch 49/100
# 125/125 [==============================] - 49s 392ms/step - loss: 0.4342 - acc: 0.7982 - val_loss: 0.4570 - val_acc: 0.7860
#
# Epoch 00049: val_acc did not improve from 0.79200
# Epoch 50/100
# 125/125 [==============================] - 45s 357ms/step - loss: 0.4463 - acc: 0.7814 - val_loss: 0.4516 - val_acc: 0.7970
#
# Epoch 00050: val_acc improved from 0.79200 to 0.79700, saving model to model_one.hdf5
# Epoch 51/100
# 125/125 [==============================] - 44s 350ms/step - loss: 0.4472 - acc: 0.7938 - val_loss: 0.4522 - val_acc: 0.7910
#
# Epoch 00051: val_acc did not improve from 0.79700
# Epoch 52/100
# 125/125 [==============================] - 45s 362ms/step - loss: 0.4247 - acc: 0.7909 - val_loss: 0.4562 - val_acc: 0.7840
#
# Epoch 00052: val_acc did not improve from 0.79700
# Epoch 53/100
# 125/125 [==============================] - 47s 375ms/step - loss: 0.4395 - acc: 0.7846 - val_loss: 0.4513 - val_acc: 0.7900
#
# Epoch 00053: val_acc did not improve from 0.79700
# Epoch 54/100
# 125/125 [==============================] - 49s 389ms/step - loss: 0.4511 - acc: 0.7767 - val_loss: 0.4456 - val_acc: 0.7960
#
# Epoch 00054: val_acc did not improve from 0.79700
# Epoch 55/100
# 125/125 [==============================] - 46s 367ms/step - loss: 0.4338 - acc: 0.7890 - val_loss: 0.4522 - val_acc: 0.7790
#
# Epoch 00055: val_acc did not improve from 0.79700
# Epoch 56/100
# 125/125 [==============================] - 48s 384ms/step - loss: 0.4240 - acc: 0.7839 - val_loss: 0.4517 - val_acc: 0.7780
#
# Epoch 00056: val_acc did not improve from 0.79700
# Epoch 57/100
# 125/125 [==============================] - 48s 384ms/step - loss: 0.4297 - acc: 0.7957 - val_loss: 0.4576 - val_acc: 0.7820
#
# Epoch 00057: val_acc did not improve from 0.79700
# Epoch 58/100
# 125/125 [==============================] - 45s 363ms/step - loss: 0.4358 - acc: 0.7905 - val_loss: 0.4365 - val_acc: 0.8010
#
# Epoch 00058: val_acc improved from 0.79700 to 0.80100, saving model to model_one.hdf5
# Epoch 59/100
# 125/125 [==============================] - 46s 366ms/step - loss: 0.4031 - acc: 0.8148 - val_loss: 0.4447 - val_acc: 0.7930
#
# Epoch 00059: val_acc did not improve from 0.80100
# Epoch 60/100
# 125/125 [==============================] - 47s 374ms/step - loss: 0.4215 - acc: 0.7869 - val_loss: 0.4312 - val_acc: 0.7960
#
# Epoch 00060: val_acc did not improve from 0.80100
# Epoch 61/100
# 125/125 [==============================] - 50s 396ms/step - loss: 0.4410 - acc: 0.7723 - val_loss: 0.4342 - val_acc: 0.7990
#
# Epoch 00061: val_acc did not improve from 0.80100
# Epoch 62/100
# 125/125 [==============================] - 49s 391ms/step - loss: 0.4348 - acc: 0.7838 - val_loss: 0.4302 - val_acc: 0.7930
#
# Epoch 00062: val_acc did not improve from 0.80100
# Epoch 63/100
# 125/125 [==============================] - 45s 356ms/step - loss: 0.4293 - acc: 0.7843 - val_loss: 0.4403 - val_acc: 0.7810
#
# Epoch 00063: val_acc did not improve from 0.80100
# Epoch 64/100
# 125/125 [==============================] - 44s 352ms/step - loss: 0.4196 - acc: 0.7970 - val_loss: 0.4175 - val_acc: 0.7940
#
# Epoch 00064: val_acc did not improve from 0.80100
# Epoch 65/100
# 125/125 [==============================] - 51s 409ms/step - loss: 0.4219 - acc: 0.7987 - val_loss: 0.4228 - val_acc: 0.8040
#
# Epoch 00065: val_acc improved from 0.80100 to 0.80400, saving model to model_one.hdf5
# Epoch 66/100
# 125/125 [==============================] - 48s 384ms/step - loss: 0.4300 - acc: 0.7980 - val_loss: 0.4108 - val_acc: 0.8010
#
# Epoch 00066: val_acc did not improve from 0.80400
# Epoch 67/100
# 125/125 [==============================] - 46s 365ms/step - loss: 0.4228 - acc: 0.7985 - val_loss: 0.4307 - val_acc: 0.7830
#
# Epoch 00067: val_acc did not improve from 0.80400
# Epoch 68/100
# 125/125 [==============================] - 47s 376ms/step - loss: 0.4028 - acc: 0.7967 - val_loss: 0.4126 - val_acc: 0.8080
#
# Epoch 00068: val_acc improved from 0.80400 to 0.80800, saving model to model_one.hdf5
# Epoch 69/100
# 125/125 [==============================] - 46s 366ms/step - loss: 0.4201 - acc: 0.8138 - val_loss: 0.4066 - val_acc: 0.8030
#
# Epoch 00069: val_acc did not improve from 0.80800
# Epoch 70/100
# 125/125 [==============================] - 45s 362ms/step - loss: 0.3927 - acc: 0.8114 - val_loss: 0.4040 - val_acc: 0.8100
#
# Epoch 00070: val_acc improved from 0.80800 to 0.81000, saving model to model_one.hdf5
# Epoch 71/100
# 125/125 [==============================] - 47s 376ms/step - loss: 0.4059 - acc: 0.7886 - val_loss: 0.4012 - val_acc: 0.8060
#
# Epoch 00071: val_acc did not improve from 0.81000
# Epoch 72/100
# 125/125 [==============================] - 48s 380ms/step - loss: 0.3778 - acc: 0.8172 - val_loss: 0.4114 - val_acc: 0.8020
#
# Epoch 00072: val_acc did not improve from 0.81000
# Epoch 73/100
# 125/125 [==============================] - 46s 365ms/step - loss: 0.4082 - acc: 0.8066 - val_loss: 0.3871 - val_acc: 0.8160
#
# Epoch 00073: val_acc improved from 0.81000 to 0.81600, saving model to model_one.hdf5
# Epoch 74/100
# 125/125 [==============================] - 45s 360ms/step - loss: 0.3848 - acc: 0.8137 - val_loss: 0.3952 - val_acc: 0.8020
#
# Epoch 00074: val_acc did not improve from 0.81600
# Epoch 75/100
# 125/125 [==============================] - 45s 362ms/step - loss: 0.3981 - acc: 0.8032 - val_loss: 0.4006 - val_acc: 0.8160
#
# Epoch 00075: val_acc did not improve from 0.81600
# Epoch 76/100
# 125/125 [==============================] - 46s 365ms/step - loss: 0.3930 - acc: 0.8028 - val_loss: 0.3857 - val_acc: 0.8190
#
# Epoch 00076: val_acc improved from 0.81600 to 0.81900, saving model to model_one.hdf5
# Epoch 77/100
# 125/125 [==============================] - 46s 364ms/step - loss: 0.3705 - acc: 0.8188 - val_loss: 0.3845 - val_acc: 0.8200
#
# Epoch 00077: val_acc improved from 0.81900 to 0.82000, saving model to model_one.hdf5
# Epoch 78/100
# 125/125 [==============================] - 48s 385ms/step - loss: 0.3713 - acc: 0.8179 - val_loss: 0.3779 - val_acc: 0.8220
#
# Epoch 00078: val_acc improved from 0.82000 to 0.82200, saving model to model_one.hdf5
# Epoch 79/100
# 125/125 [==============================] - 47s 376ms/step - loss: 0.3655 - acc: 0.8188 - val_loss: 0.3673 - val_acc: 0.8320
#
# Epoch 00079: val_acc improved from 0.82200 to 0.83200, saving model to model_one.hdf5
# Epoch 80/100
# 125/125 [==============================] - 47s 376ms/step - loss: 0.3782 - acc: 0.8114 - val_loss: 0.3649 - val_acc: 0.8330
#
# Epoch 00080: val_acc improved from 0.83200 to 0.83300, saving model to model_one.hdf5
# Epoch 81/100
# 125/125 [==============================] - 47s 374ms/step - loss: 0.3429 - acc: 0.8406 - val_loss: 0.3741 - val_acc: 0.8380
#
# Epoch 00081: val_acc improved from 0.83300 to 0.83800, saving model to model_one.hdf5
# Epoch 82/100
# 125/125 [==============================] - 47s 376ms/step - loss: 0.3534 - acc: 0.8205 - val_loss: 0.3742 - val_acc: 0.8290
#
# Epoch 00082: val_acc did not improve from 0.83800
# Epoch 83/100
# 125/125 [==============================] - 55s 444ms/step - loss: 0.3728 - acc: 0.8132 - val_loss: 0.3585 - val_acc: 0.8390
#
# Epoch 00083: val_acc improved from 0.83800 to 0.83900, saving model to model_one.hdf5
# Epoch 84/100
# 125/125 [==============================] - 69s 554ms/step - loss: 0.3618 - acc: 0.8270 - val_loss: 0.3665 - val_acc: 0.8280
#
# Epoch 00084: val_acc did not improve from 0.83900
# Epoch 85/100
# 125/125 [==============================] - 56s 446ms/step - loss: 0.3617 - acc: 0.8327 - val_loss: 0.3543 - val_acc: 0.8390
#
# Epoch 00085: val_acc did not improve from 0.83900
# Epoch 86/100
# 125/125 [==============================] - 56s 449ms/step - loss: 0.3600 - acc: 0.8315 - val_loss: 0.3582 - val_acc: 0.8200
#
# Epoch 00086: val_acc did not improve from 0.83900
# Epoch 87/100
# 125/125 [==============================] - 48s 381ms/step - loss: 0.3545 - acc: 0.8300 - val_loss: 0.3486 - val_acc: 0.8350
#
# Epoch 00087: val_acc did not improve from 0.83900
# Epoch 88/100
# 125/125 [==============================] - 45s 361ms/step - loss: 0.3440 - acc: 0.8354 - val_loss: 0.3316 - val_acc: 0.8520
#
# Epoch 00088: val_acc improved from 0.83900 to 0.85200, saving model to model_one.hdf5
# Epoch 89/100
# 125/125 [==============================] - 45s 362ms/step - loss: 0.3486 - acc: 0.8340 - val_loss: 0.3621 - val_acc: 0.8470
#
# Epoch 00089: val_acc did not improve from 0.85200
# Epoch 90/100
# 125/125 [==============================] - 47s 373ms/step - loss: 0.3335 - acc: 0.8425 - val_loss: 0.3365 - val_acc: 0.8550
#
# Epoch 00090: val_acc improved from 0.85200 to 0.85500, saving model to model_one.hdf5
# Epoch 91/100
# 125/125 [==============================] - 45s 360ms/step - loss: 0.3313 - acc: 0.8438 - val_loss: 0.3393 - val_acc: 0.8470
#
# Epoch 00091: val_acc did not improve from 0.85500
# Epoch 92/100
# 125/125 [==============================] - 46s 370ms/step - loss: 0.3388 - acc: 0.8446 - val_loss: 0.3366 - val_acc: 0.8490
#
# Epoch 00092: val_acc did not improve from 0.85500
# Epoch 93/100
# 125/125 [==============================] - 46s 367ms/step - loss: 0.3582 - acc: 0.8455 - val_loss: 0.3402 - val_acc: 0.8670
#
# Epoch 00093: val_acc improved from 0.85500 to 0.86700, saving model to model_one.hdf5
# Epoch 94/100
# 125/125 [==============================] - 47s 375ms/step - loss: 0.3408 - acc: 0.8394 - val_loss: 0.3421 - val_acc: 0.8390
#
# Epoch 00094: val_acc did not improve from 0.86700
# Epoch 95/100
# 125/125 [==============================] - 49s 388ms/step - loss: 0.3534 - acc: 0.8238 - val_loss: 0.3215 - val_acc: 0.8630
#
# Epoch 00095: val_acc did not improve from 0.86700
# Epoch 96/100
# 125/125 [==============================] - 49s 390ms/step - loss: 0.3468 - acc: 0.8348 - val_loss: 0.3455 - val_acc: 0.8380
#
# Epoch 00096: val_acc did not improve from 0.86700
# Epoch 97/100
# 110/125 [=========================>....] - ETA: 4s - loss: 0.3272 - acc: 0.8508
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0971e4ca9bbb> in <module>
# ----> 1 history, model = train_Model()
#
# <ipython-input-2-9fb6818e29bd> in train_Model()
#      60                               validation_data=test_images,
#      61                               callbacks=callbacks,
# ---> 62                               epochs=epoch)
#      63
#      64   return history, model
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
plot_history(history)

# %%
from accuracy import test_accuracy
test_accuracy(target_size=(150,150,3))
# Out:
# Acurácia:
# 71.6
